# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from scipy.interpolate import UnivariateSpline
from braid_analysis import flymath
import pynumdiff

from align_course_direction_analysis import unifying_algo_analysis as uaa

import figurefirst as fifi

# %%
def wrap_angle(a):
    return np.arctan2(np.sin(a), np.cos(a))

# %% [markdown]
# ### Parameters

# %%
fname = '../../../../../Data/Animal_Trajectory_Data/eels/eel.csv'
df_raw = pd.read_csv(fname)

flow_direction = 90*np.pi/180 + np.pi
flow_condition = 'laminar'
flow_speed = 0.21
body_length = 0.5
locomotion = 'swimming'
medium = 'water'
group = 'aquatic'

interp_dt = 0.1

# %% [markdown]
# ### Get time stamps and speed -- this is custom per data type

# %%
scaling = 1

# %%
df_calibrated = df_raw*scaling

# estimate time stamps: each point is 0.066 sec apart
timestamps = np.arange(0, df_calibrated.shape[0]*1, 1)

df_calibrated['timestamps_sec'] = timestamps

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(df_calibrated.x.values, df_calibrated.y.values)
ax.set_aspect('equal')

# %% [markdown]
# ### Interpolate

# %%
interp_timestamps_sec = np.arange(0, df_calibrated.timestamps_sec.max(), interp_dt)

spline_x = UnivariateSpline(df_calibrated.timestamps_sec, df_calibrated.x, s=1e-3, k=5)  # s=smoothing amount
interp_x = spline_x(interp_timestamps_sec)

spline_y = UnivariateSpline(df_calibrated.timestamps_sec, df_calibrated.y, s=1e-3, k=5)  # s=smoothing amount
interp_y = spline_y(interp_timestamps_sec)

df_calibrated_interp = pd.DataFrame({'timestamps_sec': interp_timestamps_sec,
                                     'x': interp_x,
                                     'y': interp_y})

# %% [markdown]
# ### Parameters

# %%
df_calibrated_interp.shape
# Out:
# (410, 3)

# %%
tix_start = 0
tix_end = 300

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(df_calibrated.x.values, df_calibrated.y.values)
ax.plot(df_calibrated_interp.x.values, df_calibrated_interp.y.values, '.')

# when does search start
ax.plot(df_calibrated_interp.x.values[tix_start], df_calibrated_interp.y.values[tix_start], 'o', color='green')

# when does search end?
ax.plot(df_calibrated_interp.x.values[tix_end], df_calibrated_interp.y.values[tix_end], 'o', color='red')

print(df_calibrated_interp.timestamps_sec.values[tix_start])

ax.set_aspect('equal')
# Out:
# 0.0

# %%
dt = np.median(np.diff(df_calibrated_interp.timestamps_sec.values))
_, xvel = pynumdiff.savgoldiff(df_calibrated_interp.x, dt, [2, 3, 3])
_, yvel = pynumdiff.savgoldiff(df_calibrated_interp.y, dt, [2, 3, 3])

# %%
df_calibrated_interp['xvel'] = xvel
df_calibrated_interp['yvel'] = yvel
df_calibrated_interp['time_relative_to_flash'] = df_calibrated_interp['timestamps_sec'] - df_calibrated_interp.timestamps_sec.values[tix_start]
df_calibrated_interp['obj_id_unique_event'] = fname.split('.')[0]
df_calibrated_interp['obj_id_unique'] = fname.split('.')[0]
df_calibrated_interp = flymath.assign_course_and_ang_vel_to_dataframe(df_calibrated_interp)

df_calibrated_interp.course_smoothish -= flow_direction + np.pi
df_calibrated_interp.course_smoothish = wrap_angle(df_calibrated_interp.course_smoothish)

# %%
plt.plot(df_calibrated_interp.course_smoothish, '.', markersize=1)

ix = df_calibrated_interp.index.values
slope = -0.04
intercept=1.8
line = slope*ix + intercept

plt.fill_betweenx([-np.pi, np.pi], tix_start, tix_end, color='yellow', alpha=0.1)

plt.plot(ix, wrap_angle(line), '.')

# %% [markdown]
# ### Parameters to set

# %%
min_ix_range = 200
max_ix_range = 300

# %%
trajec = df_calibrated_interp

# %%
course = trajec.course_smoothish.values
abs_min_ix = tix_start
abs_max_ix = tix_end

# %%
trajec['search_phase'] = np.zeros_like(trajec.x.values)
trajec.loc[tix_start:tix_end, 'search_phase']  = 1

trajec['flow_direction'] = [flow_direction]*len(trajec.x.values)
trajec['flow_condition'] = [flow_condition]*len(trajec.x.values)
trajec['flow_speed'] = [flow_speed]*len(trajec.x.values)
trajec['body_length'] = [body_length]*len(trajec.x.values)

trajec['locomotion'] = [locomotion]*len(trajec.x.values)
trajec['medium'] = [medium]*len(trajec.x.values)
trajec['group'] = [group]*len(trajec.x.values)

# %%
unifying_algo_fit = uaa.bootstrap_miop_affine_fit(course, 
                                                  abs_min_ix, abs_max_ix, min_ix_range, max_ix_range, 
                                                  npoints = np.min([min_ix_range, 50]), 
                                                  n_bootstraps=10, 
                                                  use_cvx_affine=True, 
                                                  include_translation=True, 
                                                  pis_max = 20, 
                                                  intercept_max = 4,
                                                  huber_M=1.0,
                                                  ignore_large_errors=True,
                                                  error_threshold=2.0,
                                                  large_error_penalty=1.0,
                                                  obj_id=trajec.obj_id_unique_event.values[0],
                                                  timestamps_sec=trajec.timestamps_sec,)
# Out:
# Restricted license - for non-production use only - expires 2027-11-29
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 unifying_algo_fit = uaa.bootstrap_miop_affine_fit(course,
#       2                                                   abs_min_ix, abs_max_ix, min_ix_range, max_ix_range,
#       3                                                   npoints = np.min([min_ix_range, 50]),
#       4                                                   n_bootstraps=10,
#       5                                                   use_cvx_affine=True,
#       6                                                   include_translation=True,
#       7                                                   pis_max = 20,
#       8                                                   intercept_max = 4,
#       9                                                   huber_M=1.0,
#      10                                                   ignore_large_errors=True,
#      11                                                   error_threshold=2.0,
#      12                                                   large_error_penalty=1.0,
#      13                                                   obj_id=trajec.obj_id_unique_event.values[0],
#      14                                                   timestamps_sec=trajec.timestamps_sec,)
#
# File /opt/anaconda3/envs/Python311/lib/python3.11/site-packages/align_course_direction_analysis/unifying_algo_analysis.py:149, in bootstrap_miop_affine_fit(course, abs_min_ix, abs_max_ix, min_ix_range, max_ix_range, npoints, n_bootstraps, use_cvx_affine, include_translation, pis_max, intercept_max, huber_M, ignore_large_errors, error_threshold, large_error_penalty, obj_id, timestamps_sec, slope_min, slope_max, affine_huber_M)
#     145 #print('max_ix: ', max_ix)
#     147 ix = np.sort(random_integers(min_ix, max_ix, np.min([npoints, len(course)])))
# --> 149 slope, intercept, AM = miop_and_affine_fit(course, ix,
#     150                                            min_ix, max_ix,
#     151                                            use_cvx_affine=use_cvx_affine,
#     152                                            include_translation=include_translation,
#     153                                            pis_max = pis_max,
#     154                                            intercept_max = intercept_max,
#     155                                            huber_M=huber_M,
#     156                                            ignore_large_errors=ignore_large_errors,
#     157                                            error_threshold=error_threshold,
#     158                                            large_error_penalty=large_error_penalty,
#     159                                            slope_min=slope_min,
#     160                                            slope_max=slope_max,
#     161                                            affine_huber_M=affine_huber_M)
#     163 # extract features from affine matrix
#     164 total_rotation, major_axis, minor_axis, translation = decompose_affine(AM)
#
# File /opt/anaconda3/envs/Python311/lib/python3.11/site-packages/align_course_direction_analysis/unifying_algo_analysis.py:263, in miop_and_affine_fit(course, ix, min_ix, max_ix, use_cvx_affine, include_translation, plot, pis_max, intercept_max, huber_M, ignore_large_errors, error_threshold, large_error_penalty, slope_min, slope_max, affine_huber_M)
#     233 def miop_and_affine_fit(course,
#     234                         ix,
#     235                         min_ix, max_ix,
#    (...)
#     247                         affine_huber_M=0.5,
#     248                         ):
#     250     """
#     251
#     252     Parameters:
#    (...)
#     260
#     261     """
# --> 263     slope, intercept = miop_optimization(course, ix,
#     264                                          pis_max=pis_max,
#     265                                          intercept_max=intercept_max,
#     266                                          huber_M=huber_M,
#     267                                          ignore_large_errors=ignore_large_errors,
#     268                                          error_threshold=error_threshold,
#     269                                          slope_min=slope_min,
#     270                                          slope_max=slope_max,
#     271                                          large_error_penalty=large_error_penalty)
#     273     if use_cvx_affine:
#     274         AM = find_affine_transform_cvx(course,
#     275                                        slope, intercept,
#     276                                        min_ix, max_ix,
#     277                                        affine_huber_M=affine_huber_M,
#     278                                        include_translation=include_translation)
#
# File /opt/anaconda3/envs/Python311/lib/python3.11/site-packages/align_course_direction_analysis/unifying_algo_analysis.py:396, in miop_optimization(course, ix, verbose, pis_gamma, pis_max, intercept_max, huber_M, ignore_large_errors, error_threshold, slope_min, slope_max, large_error_penalty)
#     387 constraints = [
#     388     pis >= -1*pis_max,
#     389     pis <= pis_max,
#     390     intercept >= course.min() - intercept_max,
#     391     intercept <= course.max() + intercept_max
#     392 ] + constraints_range
#     394 problem = cvxpy.Problem(objective, constraints)
# --> 396 problem.solve(solver=cvxpy.GUROBI,
#     397               verbose=verbose,
#     398               Threads=8,
#     399               Method=2,
#     400               Presolve=2,
#     401               FeasibilityTol=1e-5,
#     402               OptimalityTol=1e-5,
#     403               TimeLimit=20,
#     404               MIPGap=0.01)
#     406 if 0:
#     407     pred = (slope*ix + intercept + pis*2*np.pi).value
#
# File /opt/anaconda3/envs/Python311/lib/python3.11/site-packages/cvxpy/problems/problem.py:609, in Problem.solve(self, *args, **kwargs)
#     606         raise ValueError(
#     607             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     608     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 609 return solve_func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/Python311/lib/python3.11/site-packages/cvxpy/problems/problem.py:1222, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1220 end = time.time()
#    1221 self._solve_time = end - start
# -> 1222 self.unpack_results(solution, solving_chain, inverse_data)
#    1223 if verbose:
#    1224     print(_FOOTER)
#
# File /opt/anaconda3/envs/Python311/lib/python3.11/site-packages/cvxpy/problems/problem.py:1547, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1545     warnings.warn(INF_OR_UNB_MESSAGE)
#    1546 if solution.status in s.ERROR:
# -> 1547     raise error.SolverError(
#    1548             "Solver '%s' failed. " % chain.solver.name() +
#    1549             "Try another solver, or solve with verbose=True for more "
#    1550             "information.")
#    1552 self.unpack(solution)
#    1553 self._solver_stats = SolverStats.from_dict(self._solution.attr,
#    1554                                  chain.solver.name())
#
# SolverError: Solver 'GUROBI' failed. Try another solver, or solve with verbose=True for more information.

# %%
unifying_algo_fit['flow_direction'] = flow_direction
unifying_algo_fit['flow_condition'] = flow_condition
unifying_algo_fit['flow_speed'] = flow_speed
unifying_algo_fit['body_length'] = body_length

unifying_algo_fit['locomotion'] = locomotion
unifying_algo_fit['medium'] = medium
unifying_algo_fit['group'] = group

# %%
# Sort 
sorted_fit = unifying_algo_fit.sort_values('rmse_affine')
best_ix = sorted_fit.index[0]
best_unifying_algo_fit = unifying_algo_fit.iloc[best_ix]

# %%
sorted_fit
# Out:
#    min_ix  max_ix     slope  intercept  rotation  major_axis  minor_axis
# 4      63     270 -0.017950  -2.790018  1.410614    1.038531    0.136092  \
# 6      68     274 -0.015551   2.945632  1.416985    1.004837    0.264160
# 3      79     280 -0.015838  -3.216742  1.581284    0.947282    0.141830
# 8      75     298 -0.016729   3.083094  1.752376    0.804049   -0.048206
# 2      56     287 -0.015641   2.918714  1.560532    0.798711   -0.131982
# 5      91     296 -0.008208   1.653556  1.665872    1.194771   -0.975036
# 1      58     288 -0.008463   1.652246  1.627668    1.105917   -0.398246
# 0      65     297 -0.008281  -4.443162  1.782933    1.081252   -0.429191
# 7      48     290 -0.008531   1.838299  1.643565    1.011561   -0.353958
# 9      35     294 -0.010363  -4.016095  1.567809    0.825725   -0.080963
#
#      AM_0_0    AM_0_1    AM_1_0  ...  iteration  obj_id_unique_event
# 4  0.159050  0.142095  0.142095  ...          4                  eel  \
# 6  0.281545  0.112136  0.112136  ...          6                  eel
# 3  0.141918 -0.008446 -0.008446  ...          3                  eel
# 8 -0.020414 -0.151373 -0.151373  ...          8                  eel
# 2 -0.131884  0.009553  0.009553  ...          2                  eel
# 5 -0.955482 -0.205055 -0.205055  ...          5                  eel
# 1 -0.393387 -0.085360 -0.085360  ...          1                  eel
# 0 -0.362231 -0.310894 -0.310894  ...          0                  eel
# 7 -0.346740 -0.099017 -0.099017  ...          7                  eel
# 9 -0.080955  0.002709  0.002709  ...          9                  eel
#
#    timestep_sec  flow_direction  flow_condition  flow_speed  body_length
# 4           0.1        4.712389         laminar        0.21          0.5  \
# 6           0.1        4.712389         laminar        0.21          0.5
# 3           0.1        4.712389         laminar        0.21          0.5
# 8           0.1        4.712389         laminar        0.21          0.5
# 2           0.1        4.712389         laminar        0.21          0.5
# 5           0.1        4.712389         laminar        0.21          0.5
# 1           0.1        4.712389         laminar        0.21          0.5
# 0           0.1        4.712389         laminar        0.21          0.5
# 7           0.1        4.712389         laminar        0.21          0.5
# 9           0.1        4.712389         laminar        0.21          0.5
#
#    locomotion  medium    group
# 4    swimming   water  aquatic
# 6    swimming   water  aquatic
# 3    swimming   water  aquatic
# 8    swimming   water  aquatic
# 2    swimming   water  aquatic
# 5    swimming   water  aquatic
# 1    swimming   water  aquatic
# 0    swimming   water  aquatic
# 7    swimming   water  aquatic
# 9    swimming   water  aquatic
#
# [10 rows x 28 columns]

# %%
ix_all, course, linear_fit_angle, affine_fit_angle = uaa.build_miop_and_affine_predictions_from_model(course, best_unifying_algo_fit)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# shading for before search
ax.fill_betweenx([np.pi, -np.pi], 
                 0, 
                 abs_min_ix, 
                 color='gray', 
                 alpha=0.2, 
                 edgecolor='none', 
                 zorder=-1000)

# add shading for region of interest where fit was applied
min_ix = int(best_unifying_algo_fit.min_ix)
max_ix = int(best_unifying_algo_fit.max_ix)
ax.fill_betweenx([np.pi, -np.pi], 
                 min_ix, 
                 max_ix, 
                 color='yellow', 
                 alpha=0.2, 
                 edgecolor='none', 
                 zorder=-1000)

# plot course, linear fit, and affine fit
ax.plot(ix_all, course, '.', color='black')
ax.plot(ix_all[abs_min_ix:], linear_fit_angle[abs_min_ix:], '.', color='blue')
ax.plot(ix_all[abs_min_ix:], affine_fit_angle[abs_min_ix:], '.', color='magenta')

# Add ticks, labels, etc. 
ax.set_xlim(0, ix_all[-1])
ax.set_ylim(-np.pi, np.pi)

xticks = np.arange( np.min(ix_all), np.max(ix_all) + 50, 100)
dt = np.median(np.diff(df_calibrated_interp.timestamps_sec.values))
xticklabels = dt*xticks
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels)
ax.set_xlabel('Time, sec')

ax.set_yticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticklabels(['$-\pi$', '$-\pi/2$','$0$','$\pi/2$','$\pi$',])
ax.set_ylabel('Course')

fifi.mpl_functions.adjust_spines(ax, ['left', 'bottom'])

# %%
fname_trajec = fname.split('.')[0] + '_trajec.parquet'
trajec.to_parquet(fname_trajec)

unifying_algo_fit.to_parquet(fname.split('.')[0] + '_unifying_analysis.parquet')
