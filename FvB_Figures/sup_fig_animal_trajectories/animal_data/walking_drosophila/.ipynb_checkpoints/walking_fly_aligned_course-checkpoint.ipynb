# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from braid_analysis import braid_analysis_plots
import figurefirst as fifi

# %%
from align_course_direction_analysis import unifying_algo_analysis as uaa
from align_course_direction_analysis import unifying_algo_plots as uap

# %%
df_trajec = pd.read_parquet('MatchedOrco_chrimson_trim.parquet')

# %%
unifying_algo_data = pd.read_parquet('unifying_algo_results_MatchedOrco_chrimson_trim.parquet')

# %%
unifying_algo_data
# Out:
#     min_ix  max_ix     slope  intercept  rotation  major_axis  minor_axis
# 0     2352    2757 -0.000061   3.189391  3.031234  800.721319   52.477494  \
# 1     2124    2537  0.008014  -2.715122  3.127889    1.208581    0.761696
# 2     2404    2839 -0.007877   5.062003 -3.004923    1.101074    0.639617
# 3     2036    2474  0.007114   5.719227 -2.892567    1.116509    0.783842
# 4     2331    2829 -0.011392   1.573859  1.599295    0.589145    0.104799
# ..     ...     ...       ...        ...       ...         ...         ...
# 5     2584    2992  0.003094  -4.875996  2.260252    0.878978   -0.333892
# 6     2110    2518 -0.033206  -4.391731  1.084039    1.138638    0.495588
# 7     2475    2912 -0.007843  -7.021514  2.965060    1.156668   -0.097141
# 8     2383    2851 -0.005040   4.154446  2.545498    0.610488    0.065193
# 9     2114    2581 -0.034174   3.757551  1.031253    1.151813    0.479307
#
#         AM_0_0     AM_0_1     AM_1_0     AM_1_1          tx         ty
# 0   791.645409 -81.906173 -81.906173  61.553404  795.163284 -88.323908  \
# 1     1.208497  -0.006123  -0.006123   0.761780    0.104131  -0.022412
# 2     1.092508   0.062285   0.062285   0.648183    0.198623  -0.026257
# 3     1.096302   0.079460   0.079460   0.804049    0.080728   0.144992
# 4     0.105193  -0.013796  -0.013796   0.588752   -0.646862  -0.065127
# ..         ...        ...        ...        ...         ...        ...
# 5     0.156890  -0.595305  -0.595305   0.388196   -0.932300  -0.602403
# 6     0.636288   0.265858   0.265858   0.997938    0.044147   0.014902
# 7     1.117999  -0.216768  -0.216768  -0.058472    0.051793  -0.528158
# 8     0.438618  -0.253339  -0.253339   0.237063   -0.356627  -0.379407
# 9     0.656804   0.296416   0.296416   0.974316    0.051954   0.010975
#
#          rho  mean_residuals  axis_ratio  rmse_affine  shift_ix  iteration
# 0   0.496916        0.001173    0.065538     0.910697      2554          0  \
# 1   0.876629       -0.059228    0.630240     0.425193      2330          1
# 2   0.578015       -0.216616    0.580903     1.014090      2621          2
# 3   0.909274        0.007639    0.702047     0.393874      2255          3
# 4   0.551775       -0.035948    0.177884     0.956156      2345          4
# ..       ...             ...         ...          ...       ...        ...
# 5   0.476285       -0.049562    0.379864     0.626491      2788          5
# 6   0.880723       -0.202320    0.435247     0.567287      2139          6
# 7   0.594256       -0.073017    0.083983     0.626134      2693          7
# 8   0.167627       -0.003198    0.106788     1.179452      2617          8
# 9   0.890277        0.103689    0.416133     0.516254      2133          9
#
#    obj_id_unique_event
# 0                  0_3
# 1                  0_3
# 2                  0_3
# 3                  0_3
# 4                  0_3
# ..                 ...
# 5                24_14
# 6                24_14
# 7                24_14
# 8                24_14
# 9                24_14
#
# [500 rows x 20 columns]

# %%
result = uaa.get_aligned_course_array(  unifying_algo_data,
                                        df_trajec,
                                        apply_alignment_shift=True,
                                        normalize_slope_sign=True,
                                        xlim_start=-500,
                                        xlim_end=500,
                                        sort_using='rmse_affine',
                                        return_linear_and_affine_fits=False,
                                        shift_ix_percent=1, # if less than 1, will apply only a fraction of the shift, for build animations
                                       )

ix_master, aligned_time_since_flash_arr, aligned_course_arr, aligned_roi_arr = result

# %%
dt = np.median(np.diff(df_trajec[df_trajec.obj_id_unique_event==df_trajec.obj_id_unique_event.unique()[0]].timestamps_sec.values))

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

uap.plot_aligned_course_from_array(ix_master, 
                                   aligned_time_since_flash_arr, 
                                   aligned_course_arr, 
                                   aligned_roi_arr,
                                   aligned_flash_arr=None,
                                   aligned_linear_fits=None, 
                                   aligned_affine_fits=None,
                                   xlim_start=-500,
                                   xlim_end=500,
                                   ax=ax,
                                   clean_spines=True,
                                   course_marker_size=10,
                                   linear_marker_size=0.5,
                                   affine_marker_size=0.5,
                                   )

xticks = np.arange(-400, 500, 200)
ax.set_xticks(xticks)
ax.set_xticklabels( (xticks*dt).astype('int'))
ax.set_xlabel('Aligned time, sec')

#ax.set_yticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
#ax.set_yticklabels(['$-\pi$', '$-\pi/2$','$0$','$\pi/2$','$\pi$',])
ax.set_ylabel('Course')

fifi.mpl_functions.adjust_spines(ax, ['left', 'bottom'])

# %%
unifying_algo_data['abs_slope'] = np.abs(unifying_algo_data.slope)
unifying_algo_data['abs_rho'] = np.abs(unifying_algo_data.rho)

# %%
weighted_slopes = []
weighted_rho = []
for objid in unifying_algo_data.obj_id_unique_event.unique():
    unifying_algo_data_trajec = unifying_algo_data[unifying_algo_data.obj_id_unique_event==objid]
    rho = uaa.get_weighted_value(unifying_algo_data_trajec, col='abs_rho', use='rmse_affine')
    slope = uaa.get_weighted_value(unifying_algo_data_trajec, col='abs_slope', use='rmse_affine')
    weighted_slopes.append(slope/dt)
    weighted_rho.append(rho)

# %%
plt.hist(weighted_rho)
# Out:
# (array([6., 5., 3., 6., 0., 9., 9., 8., 2., 2.]),
#  array([0.28883478, 0.34867353, 0.40851228, 0.46835104, 0.52818979,
#         0.58802855, 0.6478673 , 0.70770606, 0.76754481, 0.82738356,
#         0.88722232]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(weighted_slopes)
# Out:
# (array([8., 7., 6., 6., 8., 4., 3., 3., 2., 3.]),
#  array([0.09167387, 0.30080337, 0.50993286, 0.71906236, 0.92819185,
#         1.13732135, 1.34645085, 1.55558034, 1.76470984, 1.97383933,
#         2.18296883]),
#  <BarContainer object of 10 artists>)
